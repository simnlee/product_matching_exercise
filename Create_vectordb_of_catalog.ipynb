# %% [markdown]
# # Set api key

# %%
import getpass
import os

os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %% [markdown]
# # create vectordb

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
vector_store = Chroma(
    collection_name="collection2",
    embedding_function=embeddings,
    persist_directory="./chrome_vector_db",
)

# %%
from pydantic import BaseModel, Field
from typing import Optional

class Attributes(BaseModel):
    length: Optional[float] = Field(default=None, description="length in inches. if the name uses different units, convert to inches")
    gauge: Optional[int] = Field(default=None, description="gauge in inches. for example, 20ga or 20g refers to 20 gauge")

# %%
import pandas as pd

catalog_df = pd.read_csv("documents/ProductDB_clean.csv")

# %%
catalog_df
# Out:
#       PRODUCT_ID  PRODUCT_NO                        NAME             ALIAS  \
# 0           4802        1011  18MIL 1-5/8IN DRYWALL STUD        162S125-18
# 1           4804        1013    DRYWALL STUD 1-5/8IN 20G  162S125-30 (20G)
# 2           4806        1021  18MIL 2-1/2IN DRYWALL STUD        250S125-18
# 3           4808        1023    DRYWALL STUD 2-1/2IN 20G  250S125-30 (20G)
# 4           4811        1031  18MIL 3-5/8IN DRYWALL STUD        362S125-18
# ...          ...         ...                         ...               ...
# 9808        9099       99942         ANGL 1.5 X 2 (14GA)               NaN
# 9809        9102       99947       WBS 400 X 13.75 IN-14               NaN
# 9810       35945      999995            Price Protection               NaN
# 9811       11808      999998                Generic Part               NaN
# 9812       11246      999999             Generic Product               NaN
#
#       STATUS PRODUCT_LINE_CODE PRODUCT_GROUP_CODE PRODUCT_CODE_CODE  Product  \
# 0          1              FRAM                DWF               DWS     1011
# 1          1              FRAM                DWF               DWS     1013
# 2          1              FRAM                DWF               DWS     1021
# 3          1              FRAM                DWF               DWS     1023
# 4          1              FRAM                DWF               DWS     1031
# ...      ...               ...                ...               ...      ...
# 9808       1              FRAM                ACC              ANGL    99942
# 9809       1              CONN               BRAC               WBS    99947
# 9810       1              MISC               MISC              MISC   999995
# 9811       1              FRAM                ACC              ANGL   999998
# 9812       1              FRAM                STF              TRAK   999999
#
#                   SFIA
# 0           162S125-18
# 1     162S125-30 (20G)
# 2           250S125-18
# 3     250S125-30 (20G)
# 4           362S125-18
# ...                ...
# 9808        150L200-68
# 9809         400WBS-68
# 9810  Price Protection
# 9811      Generic Part
# 9812                 0
#
# [9813 rows x 10 columns]

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4o-mini-2024-07-18", temperature=0)
structured_llm = model.with_structured_output(Attributes)

# %%
from langchain_core.prompts.chat import ChatPromptTemplate
get_attr_prompt_template = ChatPromptTemplate.from_template("Parse all given attributes from the given product name. If the attribute isn't present in the name, or you are unsure, then leave it as None. If a measurement is written like 2-1/2IN, then the measurement is 2.5 in. \nProduct Name: {product_name}")

# %%
get_attr_prompt = get_attr_prompt_template.invoke({'product_name': 'DRYWALL STUD 1-5/8IN 20G'})
structured_llm.invoke(get_attr_prompt)
# Out:
# Attributes(length=1.625, gauge=20)

# %%
from langchain_core.documents import Document
for index, row in catalog_df.iterrows():
    product_name = str(row["NAME"])
    alias = str(row["ALIAS"])
    name = product_name + " " + alias
    get_attr_prompt = get_attr_prompt_template.invoke({'product_name': name})
    parsed_attributes = structured_llm.invoke(get_attr_prompt)
    attr_dict = dict(parsed_attributes)
    metadata = {key:val for key, val in attr_dict.items() if val is not None}
    metadata['PRODUCT_NO'] = row["PRODUCT_NO"]
    document = Document(page_content=name, metadata=metadata)
    vector_store.add_documents([document])
    print(f"Added document {index+1}/{len(catalog_df)} with name {name} and attributes length {attr_dict['length']} and gauge {attr_dict['gauge']}")
# Out:
# Added document 1/9813 with name 18MIL 1-5/8IN DRYWALL STUD 162S125-18 and attributes length 1.625 and gauge 18
# Added document 2/9813 with name DRYWALL STUD 1-5/8IN 20G 162S125-30 (20G) and attributes length 1.625 and gauge 20
# Added document 3/9813 with name 18MIL 2-1/2IN DRYWALL STUD 250S125-18 and attributes length 2.5 and gauge 18
# Added document 4/9813 with name DRYWALL STUD 2-1/2IN 20G 250S125-30 (20G) and attributes length 2.5 and gauge 20
# Added document 5/9813 with name 18MIL 3-5/8IN DRYWALL STUD 362S125-18 and attributes length 3.625 and gauge 18
# Added document 6/9813 with name 18MIL 4IN DRYWALL STUD 400S125-18 and attributes length 4.0 and gauge 18
# Added document 7/9813 with name DRYWALL STUD 4IN 20G 400S125-30 (20G) and attributes length 4.0 and gauge 20
# Added document 8/9813 with name 18MIL 6IN DRYWALL STUD 600S125-18 and attributes length 6.0 and gauge 18
# Added document 9/9813 with name 10FT GALVANIZED BULLNOSE CORNER BEAD nan and attributes length 120.0 and gauge None
# Added document 10/9813 with name STRUCTURAL STUD 2-1/2IN 20G 1-3/8IN FL 250S137-33 (20G) and attributes length 2.5 and gauge 20
# Added document 11/9813 with name STRUCTURAL STUD 2-1/2IN 18G 1-3/8IN FL 250S137-43 (18G) and attributes length 2.5 and gauge 18
# Added document 12/9813 with name STRUCTURAL STUD 2-1/2IN 16G 1-3/8IN FL 250S137-54 (16G) and attributes length 2.5 and gauge 16
# Added document 13/9813 with name STRUCTURAL STUD 2-1/2IN 14G 1-3/8IN FL 250S137-68 (14G) and attributes length 2.5 and gauge 14
# Added document 14/9813 with name STRUCTURAL STUD 2-1/2IN 12G 1-3/8IN FL 250S137-97 (12G) and attributes length 2.5 and gauge 12
# Added document 15/9813 with name STRUCTURAL STUD 3-5/8IN 20G 1-3/8IN FL 362S137-33 (20G) and attributes length 3.625 and gauge 20
# Added document 16/9813 with name STRUCTURAL STUD 3-5/8IN 18G 1-3/8IN FL 362S137-43 (18G) and attributes length 3.625 and gauge 18
# Added document 17/9813 with name STRUCTURAL STUD 3-5/8IN 16G 1-3/8IN FL 362S137-54 (16G) and attributes length 3.625 and gauge 16
# Added document 18/9813 with name STRUCTURAL STUD 3-5/8IN 14G 1-3/8IN FL 362S137-68 (14G) and attributes length 3.625 and gauge 14
# Added document 19/9813 with name STRUCTURAL STUD 3-5/8IN 12G 1-3/8IN FL 362S137-97 (12G) and attributes length 3.625 and gauge 12
# Added document 20/9813 with name STRUCTURAL STUD 4IN 20G 1-3/8IN FL 400S137-33 (20G) and attributes length 4.0 and gauge 20
# Added document 21/9813 with name STRUCTURAL STUD 4IN 18G 1-3/8IN FL 400S137-43 (18G) and attributes length 1.375 and gauge 18
# Added document 22/9813 with name STRUCTURAL STUD 4IN 16G 1-3/8IN FL 400S137-54 (16G) and attributes length 1.375 and gauge 16
# Added document 23/9813 with name STRUCTURAL STUD 4IN 14G 1-3/8IN FL 400S137-68 (14G) and attributes length 1.375 and gauge 14
# Added document 24/9813 with name STRUCTURAL STUD 5-1/2IN 20G 1-3/8IN FL 550S137-33 (20G) and attributes length 5.5 and gauge 20
# Added document 25/9813 with name STRUCTURAL STUD 5-1/2IN 18G 1-3/8IN FL 550S137-43 (18G) and attributes length 5.5 and gauge 18
# Added document 26/9813 with name STRUCTURAL STUD 5-1/2IN 16G 1-3/8IN FL 550S137-54 (16G) and attributes length 5.5 and gauge 16
# Added document 27/9813 with name STRUCTURAL STUD 6IN 20G 1-3/8IN FL 600S137-33 (20G) and attributes length 6.0 and gauge 20
# Added document 28/9813 with name STRUCTURAL STUD 6IN 18G 1-3/8IN FL 600S137-43 (18G) and attributes length 6.0 and gauge 18
# Added document 29/9813 with name STRUCTURAL STUD 6IN 16G 1-3/8IN FL 600S137-54 (16G) and attributes length 6.0 and gauge 16
# Added document 30/9813 with name STRUCTURAL STUD 6IN 14G 1-3/8IN FL 600S137-68 (14G) and attributes length 6.0 and gauge 14
# Added document 31/9813 with name STRUCTURAL STUD 6IN 12G 1-3/8IN FL 600S137-97 (12G) and attributes length 6.0 and gauge 12
# Added document 32/9813 with name STRUCTURAL STUD 8IN 20G 1-3/8IN FL 800S137-33 (20G) and attributes length 8.0 and gauge 20
# Added document 33/9813 with name STRUCTURAL STUD 8IN 18G 1-3/8IN FL 800S137-43 (18G) and attributes length 8.0 and gauge 18
# Added document 34/9813 with name STRUCTURAL STUD 8IN 16G 1-3/8IN FL 800S137-54 (16G) and attributes length 8.0 and gauge 16
# Added document 35/9813 with name STRUCTURAL STUD 8IN 14G 1-3/8IN FL 800S137-68 (14G) and attributes length 8.0 and gauge 14
# Added document 36/9813 with name STRUCTURAL STUD 8IN 12G 1-3/8IN FL 800S137-97 (12G) and attributes length 8.0 and gauge 12
# Added document 37/9813 with name STRUCTURAL STUD 10IN 20G 1-3/8IN FL 1000S137-33 (20G) and attributes length 10.0 and gauge 20
# Added document 38/9813 with name STRUCTURAL STUD 10IN 18G 1-3/8IN FL 1000S137-43 (18G) and attributes length 10.0 and gauge 18
# Added document 39/9813 with name STRUCTURAL STUD 10IN 16G 1-3/8IN FL 1000S137-54 (16G) and attributes length 10.0 and gauge 16
# Added document 40/9813 with name STRUCTURAL STUD 10IN 14G 1-3/8IN FL 1000S137-68 (14G) and attributes length 10.0 and gauge 14
# Added document 41/9813 with name STRUCTURAL STUD 10IN 12G 1-3/8IN FL 1000S137-97 (12G) and attributes length 10.0 and gauge 12
# Added document 42/9813 with name STRUCTURAL STUD 12IN 20G 1-3/8IN FL 1200S137-33 (20G) and attributes length 12.0 and gauge 20
# Added document 43/9813 with name STRUCTURAL STUD 12IN 16G 1-3/8IN FL 1200S137-54 (16G) and attributes length 12.0 and gauge 16
# Added document 44/9813 with name STRUCTURAL STUD 12IN 14G 1-3/8IN FL 1200S137-68 (14G) and attributes length 12.0 and gauge 14
# Added document 45/9813 with name STRUCTURAL STUD 12IN 12G 1-3/8IN FL 1200S137-97 (12G) and attributes length 12.0 and gauge 12
# Added document 46/9813 with name 10FT VINYL BULLNOSE ARCH CORNER BEAD nan and attributes length 120.0 and gauge None
# Added document 47/9813 with name STRUCTURAL STUD 3-1/2IN 20G 1-3/8IN FL 350S137-33 (20G) and attributes length 3.5 and gauge 20
# Added document 48/9813 with name STRUCTURAL STUD 3-1/2IN 18G 1-3/8IN FL 350S137-43 (18G) and attributes length 3.5 and gauge 18
# Added document 49/9813 with name STRUCTURAL STUD 3-1/2IN 16G 1-3/8IN FL 350S137-54 (16G) and attributes length 3.5 and gauge 16
# Added document 50/9813 with name STRUCTURAL STUD 5IN 20G 1-3/8IN FL 500S137-33 (20G) and attributes length 5.0 and gauge 20
# Added document 51/9813 with name STRUCTURAL STUD 6-3/4IN 18G 1-5/8IN FL 675S162-43 (18G) and attributes length 6.75 and gauge 18
# Added document 52/9813 with name AB - .050 - 500 PC BOX BREAKAWAY CLIP .050 - 500 PC BOX and attributes length None and gauge 50
# Added document 53/9813 with name AB - .050 - 500 PC BUCKET BC-050 and attributes length None and gauge 50
# Added document 54/9813 with name AB63 BREAKAWAY CLIP .063 and attributes length None and gauge 63
# Added document 55/9813 with name AB45 nan and attributes length None and gauge None
# Added document 56/9813 with name AB40 nan and attributes length None and gauge None
# Added document 57/9813 with name AB35 nan and attributes length None and gauge None
# Added document 58/9813 with name AB30 nan and attributes length None and gauge None
# Added document 59/9813 with name BREAKAWAY CLIP .050 - 250 PC BOX BC-050 and attributes length None and gauge 50
# Added document 60/9813 with name 18MIL 3-1/2IN DRYWALL STUD 350S125-18 and attributes length 3.5 and gauge 18
# Added document 61/9813 with name STRUCTURAL STUD 1-5/8IN 20G 1-5/8IN FL 162S162-33 (20G) and attributes length 1.625 and gauge 20
# Added document 62/9813 with name STRUCTURAL STUD 1-5/8IN 18G 1-5/8IN FL 162S162-43 (18G) and attributes length 1.625 and gauge 18
# Added document 63/9813 with name STRUCTURAL STUD 1-5/8IN 16G 1-5/8IN FL 162S162-54 (16G) and attributes length 1.625 and gauge 16
# Added document 64/9813 with name STRUCTURAL STUD 2-1/2IN 20G 1-5/8IN FL 250S162-33 (20G) and attributes length 2.5 and gauge 20
# Added document 65/9813 with name STRUCTURAL STUD 2-1/2IN 18G 1-5/8IN FL 250S162-43 (18G) and attributes length 2.5 and gauge 18
# Added document 66/9813 with name STRUCTURAL STUD 2-1/2IN 16G 1-5/8IN FL 250S162-54 (16G) and attributes length 2.5 and gauge 16
# Added document 67/9813 with name STRUCTURAL STUD 2-1/2IN 14G 1-5/8IN FL 250S162-68 (14G) and attributes length 2.5 and gauge 14
# Added document 68/9813 with name STRUCTURAL STUD 2-1/2IN 12G 1-5/8IN FL 250S162-97 (12G) and attributes length 2.5 and gauge 12
# Added document 69/9813 with name STRUCTURAL STUD 3-5/8IN 20G 1-5/8IN FL 362S162-33 (20G) and attributes length 1.625 and gauge 20
# Added document 70/9813 with name STRUCTURAL STUD 3-5/8IN 18G 1-5/8IN FL 362S162-43 (18G) and attributes length 1.625 and gauge 18
# Added document 71/9813 with name STRUCTURAL STUD 3-5/8IN 16G 1-5/8IN FL 362S162-54 (16G) and attributes length 3.625 and gauge 16
# Added document 72/9813 with name STRUCTURAL STUD 3-5/8IN 14G 1-5/8IN FL 362S162-68 (14G) and attributes length 1.625 and gauge 14
# Added document 73/9813 with name STRUCTURAL STUD 3-5/8IN 12G 1-5/8IN FL 362S162-97 (12G) and attributes length 1.625 and gauge 12
# Added document 74/9813 with name STRUCTURAL STUD 3-5/8IN 10G 1-5/8IN FL 362S162-118 (10G) and attributes length 3.625 and gauge 10
# Added document 75/9813 with name STRUCTURAL STUD 4IN 20G 1-5/8IN FL 400S162-33 (20G) and attributes length 1.625 and gauge 20
# Added document 76/9813 with name STRUCTURAL STUD 4IN 18G 1-5/8IN FL 400S162-43 (18G) and attributes length 1.625 and gauge 18
# Added document 77/9813 with name STRUCTURAL STUD 4IN 16G 1-5/8IN FL 400S162-54 (16G) and attributes length 1.625 and gauge 16
# Added document 78/9813 with name STRUCTURAL STUD 4IN 14G 1-5/8IN FL 400S162-68 (14G) and attributes length 1.625 and gauge 14
# Added document 79/9813 with name STRUCTURAL STUD 4IN 12G 1-5/8IN FL 400S162-97 (12G) and attributes length 1.625 and gauge 12
# Added document 80/9813 with name STRUCTURAL STUD 4IN 10G 1-5/8IN FL 400S162-118 (10G) and attributes length 1.625 and gauge 10
# Added document 81/9813 with name STRUCTURAL STUD 5-1/2IN 20G 1-5/8IN FL 550S162-33 (20G) and attributes length 5.5 and gauge 20
# Added document 82/9813 with name STRUCTURAL STUD 5-1/2IN 18G 1-5/8IN FL 550S162-43 (18G) and attributes length 5.5 and gauge 18
# Added document 83/9813 with name STRUCTURAL STUD 5-1/2IN 16G 1-5/8IN FL 550S162-54 (16G) and attributes length 5.5 and gauge 16
# Added document 84/9813 with name STRUCTURAL STUD 5-1/2IN 14G 1-5/8IN FL 550S162-68 (14G) and attributes length 5.5 and gauge 14
# Added document 85/9813 with name STRUCTURAL STUD 5-1/2IN 12G 1-5/8IN FL 550S162-97 (12G) and attributes length 5.5 and gauge 12
# Added document 86/9813 with name STRUCTURAL STUD 5-1/2IN 10G 1-5/8IN FL 550S162-118 (10G) and attributes length 5.5 and gauge 10
# Added document 87/9813 with name STRUCTURAL STUD 6IN 20G 1-5/8IN FL 600S162-33 (20G) and attributes length 6.0 and gauge 20
# Added document 88/9813 with name STRUCTURAL STUD 6IN 18G 1-5/8IN FL 600S162-43 (18G) and attributes length 6.0 and gauge 18
# Added document 89/9813 with name STRUCTURAL STUD 6IN 16G 1-5/8IN FL 600S162-54 (16G) and attributes length 6.0 and gauge 16
# Added document 90/9813 with name STRUCTURAL STUD 6IN 14G 1-5/8IN FL 600S162-68 (14G) and attributes length 6.0 and gauge 14
# Added document 91/9813 with name STRUCTURAL STUD 6IN 12G 1-5/8IN FL 600S162-97 (12G) and attributes length 6.0 and gauge 12
# Added document 92/9813 with name STRUCTURAL STUD 6IN 10G 1-5/8IN FL 600S162-118 (10G) and attributes length 6.0 and gauge 10
# Added document 93/9813 with name STRUCTURAL STUD 7-1/4IN 20G 1-5/8IN FL 725S162-33 (20G) and attributes length 7.25 and gauge 20
# Added document 94/9813 with name STRUCTURAL STUD 7-1/4IN 18G 1-5/8IN FL 725S162-43 (18G) and attributes length 7.25 and gauge 18
# Added document 95/9813 with name STRUCTURAL STUD 7-1/4IN 16G 1-5/8IN FL 725S162-54 (16G) and attributes length 7.25 and gauge 16
# Added document 96/9813 with name STRUCTURAL STUD 7-1/4IN 14G 1-5/8IN FL 725S162-68 (14G) and attributes length 7.25 and gauge 14
# Added document 97/9813 with name STRUCTURAL STUD 7-1/4IN 12G 1-5/8IN FL 725S162-97 (12G) and attributes length 7.25 and gauge 12
# Added document 98/9813 with name STRUCTURAL STUD 8IN 20G 1-5/8IN FL 800S162-33 (20G) and attributes length 8.0 and gauge 20
# Added document 99/9813 with name STRUCTURAL STUD 8IN 18G 1-5/8IN FL 800S162-43 (18G) and attributes length 8.0 and gauge 18
# Added document 100/9813 with name STRUCTURAL STUD 8IN 16G 1-5/8IN FL 800S162-54 (16G) and attributes length 8.0 and gauge 16
# Added document 101/9813 with name STRUCTURAL STUD 8IN 14G 1-5/8IN FL 800S162-68 (14G) and attributes length 8.0 and gauge 14
# Added document 102/9813 with name STRUCTURAL STUD 8IN 12G 1-5/8IN FL 800S162-97 (12G) and attributes length 8.0 and gauge 12
# Added document 103/9813 with name STRUCTURAL STUD 8IN 10G 1-5/8IN FL 800S162-118 (10G) and attributes length 8.0 and gauge 10
# Added document 104/9813 with name STRUCTURAL STUD 9-1/2IN 14G 1-5/8IN FL 950S162-68 (14G) and attributes length 9.5 and gauge 14
# Added document 105/9813 with name STRUCTURAL STUD 9-1/4IN 18G 1-5/8IN FL 925S162-43 (18G) and attributes length 9.25 and gauge 18
# Added document 106/9813 with name STRUCTURAL STUD 9-1/4IN 16G 1-5/8IN FL 925S162-54 (16G) and attributes length 9.25 and gauge 16
# Added document 107/9813 with name STRUCTURAL STUD 9-1/4IN 14G 1-5/8IN FL 925S162-68 (14G) and attributes length 9.25 and gauge 14
# Added document 108/9813 with name STRUCTURAL STUD 9-1/4IN 12G 1-5/8IN FL 925S162-97 (12G) and attributes length 9.25 and gauge 12
# Added document 109/9813 with name STRUCTURAL STUD 10IN 20G 1-5/8IN FL 1000S162-33 (20G) and attributes length 10.0 and gauge 20
# Added document 110/9813 with name STRUCTURAL STUD 10IN 18G 1-5/8IN FL 1000S162-43 (18G) and attributes length 10.0 and gauge 18
# Added document 111/9813 with name STRUCTURAL STUD 10IN 16G 1-5/8IN FL 1000S162-54 (16G) and attributes length 10.0 and gauge 16
# Added document 112/9813 with name STRUCTURAL STUD 10IN 14G 1-5/8IN FL 1000S162-68 (14G) and attributes length 10.0 and gauge 14
# Added document 113/9813 with name STRUCTURAL STUD 10IN 12G 1-5/8IN FL 1000S162-97 (12G) and attributes length 10.0 and gauge 12
# Added document 114/9813 with name STRUCTURAL STUD 10IN 10G 1-5/8IN FL 1000S162-118 (10G) and attributes length 10.0 and gauge 10
# Added document 115/9813 with name STRUCTURAL STUD 11-1/2IN 18G 1-5/8IN FL 1150S162-43 (18G) and attributes length 11.5 and gauge 18
# Added document 116/9813 with name STRUCTURAL STUD 11-1/2IN 16G 1-5/8IN FL 1150S162-54 (16G) and attributes length 11.5 and gauge 16
# Added document 117/9813 with name STRUCTURAL STUD 11-1/2IN 14G 1-5/8IN FL 1150S162-68 (14G) and attributes length 11.5 and gauge 14
# Added document 118/9813 with name STRUCTURAL STUD 11-1/2IN 12G 1-5/8IN FL 1150S162-97 (12G) and attributes length 11.5 and gauge 12
# Added document 119/9813 with name STRUCTURAL STUD 12IN 20G 1-5/8IN FL 1200S162-33 (20G) and attributes length 12.0 and gauge 20
# Added document 120/9813 with name STRUCTURAL STUD 12IN 18G 1-5/8IN FL 1200S162-43 (18G) and attributes length 12.0 and gauge 18
# Added document 121/9813 with name STRUCTURAL STUD 12IN 16G 1-5/8IN FL 1200S162-54 (16G) and attributes length 12.0 and gauge 16
# Added document 122/9813 with name STRUCTURAL STUD 12IN 14G 1-5/8IN FL 1200S162-68 (14G) and attributes length 12.0 and gauge 14
# Added document 123/9813 with name STRUCTURAL STUD 12IN 12G 1-5/8IN FL 1200S162-97 (12G) and attributes length 12.0 and gauge 12
# Added document 124/9813 with name STRUCTURAL STUD 12IN 10G 1-5/8IN FL 1200S162-118 (10G) and attributes length 12.0 and gauge 10
# Added document 125/9813 with name STRUCTURAL STUD 14IN 20G 1-5/8IN FL 1400S162-33 (20G) and attributes length 14.0 and gauge 20
# Added document 126/9813 with name STRUCTURAL STUD 14IN 18G 1-5/8IN FL 1400S162-43 (18G) and attributes length 14.0 and gauge 18
# Added document 127/9813 with name STRUCTURAL STUD 14IN 16G 1-5/8IN FL 1400S162-54 (16G) and attributes length 14.0 and gauge 16
# Added document 128/9813 with name STRUCTURAL STUD 14IN 14G 1-5/8IN FL 1400S162-68 (14G) and attributes length 14.0 and gauge 14
# Added document 129/9813 with name STRUCTURAL STUD 14IN 12G 1-5/8IN FL 1400S162-97 (12G) and attributes length 14.0 and gauge 12
# Added document 130/9813 with name STRUCTURAL STUD 14IN 10G 1-5/8IN FL 1400S162-118 (10G) and attributes length 14.0 and gauge 10
# Added document 131/9813 with name STRUCTURAL STUD 16IN 18G 1-5/8IN FL 1600S162-43 (18G) and attributes length 16.0 and gauge 18
# Added document 132/9813 with name STRUCTURAL STUD 16IN 16G 1-5/8IN FL 1600S162-54 (16G) and attributes length 16.0 and gauge 16
# Added document 133/9813 with name STRUCTURAL STUD 16IN 14G 1-5/8IN FL 1600S162-68 (14G) and attributes length 16.0 and gauge 14
# Added document 134/9813 with name STRUCTURAL STUD 16IN 12G 1-5/8IN FL 1600S162-97 (12G) and attributes length 16.0 and gauge 12
# Added document 135/9813 with name STRUCTURAL STUD 16IN 10G 1-5/8IN FL 1600S162-118 (10G) and attributes length 16.0 and gauge 10
# Added document 136/9813 with name STRUCTURAL STUD 7-1/2IN 18G 1-5/8IN FL 750S162-43 (18G) and attributes length 7.5 and gauge 18
# Added document 137/9813 with name STRUCTURAL STUD 3-1/2IN 20G 1-5/8IN FL 350S162-33 (20G) and attributes length 3.5 and gauge 20
# Added document 138/9813 with name STRUCTURAL STUD 3-1/2IN 18G 1-5/8IN FL 350S162-43 (18G) and attributes length 3.5 and gauge 18
# Added document 139/9813 with name STRUCTURAL STUD 3-1/2IN 16G 1-5/8IN FL 350S162-54 (16G) and attributes length 3.5 and gauge 16
# Added document 140/9813 with name STRUCTURAL STUD 3-1/2IN 14G 1-5/8IN FL 350S162-68 (14G) and attributes length 3.5 and gauge 14
# Added document 141/9813 with name STRUCTURAL STUD 3-1/2IN 12G 1-5/8IN FL 350S162-97 (12G) and attributes length 3.5 and gauge 12
# Added document 142/9813 with name STRUCTURAL STUD 4-1/2IN 20G 1-5/8IN FL 450S162-33 (20G) and attributes length 4.5 and gauge 20
# Added document 143/9813 with name STRUCTURAL STUD 5IN 20G 1-5/8IN FL 500S162-33 (20G) and attributes length 5.0 and gauge 20
# Added document 144/9813 with name STRUCTURAL STUD 5IN 18G 1-5/8IN FL 500S162-43 (18G) and attributes length 5.0 and gauge 18
# Added document 145/9813 with name STRUCTURAL STUD 5IN 16G 1-5/8IN FL 500S162-54 (16G) and attributes length 5.0 and gauge 16
# Added document 146/9813 with name STRUCTURAL STUD 7-1/2IN 20G 1-5/8IN FL 750S162-33 (20G) and attributes length 7.5 and gauge 20
# Added document 147/9813 with name STRUCTURAL STUD 6IN 20G 1-5/8IN FL 600S162-33 (20G) and attributes length 6.0 and gauge 20
# Added document 148/9813 with name STRUCTURAL STUD 9-1/2IN 18G 1-5/8IN FL 950S162-43 (18G) and attributes length 9.5 and gauge 18
# Added document 149/9813 with name ProSTUD 20 LTD 1-5/8IN DRYWALL STUD 162PDS125-19 and attributes length 1.625 and gauge 20
# Added document 150/9813 with name ProSTUD 22MIL-33EQ 1-5/8 DRYWALL STUD 162PDS125-22 (33EQ) and attributes length 1.625 and gauge 22
# Added document 151/9813 with name ProSTUD 20 LTD 2-1/2IN DRYWALL STUD 250PDS125-19 and attributes length 2.5 and gauge 20
# Added document 152/9813 with name ProSTUD 22MIL-33EQ 2-1/2 DRYWALL STUD 250PDS125-22 (33EQ) and attributes length 2.5 and gauge 22
# Added document 153/9813 with name ProSTUD 20 LTD 3-5/8IN DRYWALL STUD 362PDS125-19 and attributes length 3.625 and gauge 20
# Added document 154/9813 with name ProSTUD 22MIL-33EQ 3-5/8 DRYWALL STUD 362PDS125-22 (33EQ) and attributes length 3.625 and gauge 22
# Added document 155/9813 with name ProSTUD 20 LTD 4IN DRYWALL STUD 400PDS125-19 and attributes length 4.0 and gauge 20
# Added document 156/9813 with name ProSTUD 22MIL-33EQ 4 DRYWALL STUD 400PDS125-22 (33EQ) and attributes length None and gauge 22
# Added document 157/9813 with name ProSTUD 20 LTD 6IN DRYWALL STUD 600PDS125-19 and attributes length 6.0 and gauge 20
# Added document 158/9813 with name ProSTUD 22MIL-33EQ 6 DRYWALL STUD 600PDS125-22 (33EQ) and attributes length None and gauge 22
# Added document 159/9813 with name ProSTUD 20 LTD 3-1/2IN DRYWALL STUD 350PDS125-19 and attributes length 3.5 and gauge 20
# Added document 160/9813 with name ProSTUD 22MIL-33EQ 3-1/2 DRYWALL STUD 350PDS125-22 (33EQ) and attributes length 3.5 and gauge 22
# Added document 161/9813 with name ProSTUD 20 LTD 5-1/2IN DRYWALL STUD 550PDS125-19 and attributes length 5.5 and gauge 20
# Added document 162/9813 with name ProTRAK 20 LTD 1-5/8IN DW TR 1-1/2IN LEG 162PDT150-19 and attributes length 1.5 and gauge 20
# Added document 163/9813 with name ProTRAK 22MIL-33EQ 1-5/8 DW TRK 1-1/2LEG 162PDT150-22 (33EQ) and attributes length 1.5 and gauge 22
# Added document 164/9813 with name ProTRAK 20 LTD 2-1/2IN DW TR 1-1/2IN LEG 250PDT150-19 and attributes length 2.5 and gauge 20
# Added document 165/9813 with name ProTRAK 22MIL-33EQ 2-1/2 DW TRK 1-1/2LEG 250PDT150-22 (33EQ) and attributes length 2.5 and gauge 22
# Added document 166/9813 with name ProTRAK 20 LTD 4IN DW TRACK 1-1/2IN LEG 400PDT150-19 and attributes length 4.0 and gauge 20
# Added document 167/9813 with name ProTRAK 22MIL-33EQ 4 DW TRACK 1-1/2 LEG 400PDT150-22 (33EQ) and attributes length 1.5 and gauge 22
# Added document 168/9813 with name ProTRAK 20 LTD 5-1/2IN DW TR 1-1/2IN LEG 550PDT150-19 and attributes length 5.5 and gauge 20
# Added document 169/9813 with name ProTRAK 20 LTD 6IN DW TRACK 1-1/2IN LEG 600PDT150-19 and attributes length 6.0 and gauge 20
# Added document 170/9813 with name ProTRAK 22MIL-33EQ 6 DW TRACK 1-1/2 LEG 600PDT150-22 (33EQ) and attributes length 1.5 and gauge 22
# Added document 171/9813 with name ProTRAK 20 LTD 1-5/8IN DW TRACK 1IN LEG 162PDT100-19 and attributes length 1.625 and gauge 20
# Added document 172/9813 with name ProTRAK 22MIL-33EQ 1-5/8 DW TRACK 1 LEG 162PDT100-22 (33EQ) and attributes length 1.625 and gauge 22
# Added document 173/9813 with name ProTRAK 20 LTD 2-1/2IN DW TRACK 1IN LEG 250PDT100-19 and attributes length 2.5 and gauge 20
# Added document 174/9813 with name ProTRAK 20 LTD 3-5/8IN DW TRACK 1IN LEG 362PDT100-19 and attributes length 3.625 and gauge 20
# Added document 175/9813 with name ProTRAK 22MIL-33EQ 3-5/8 DW TRACK 1 LEG 362PDT100-22 (33EQ) and attributes length 3.625 and gauge 22
# Added document 176/9813 with name ProTRAK 20 LTD 4IN DRYWALL TRACK 1IN LEG 400PDT100-19 and attributes length 4.0 and gauge 20
# Added document 177/9813 with name ProTRAK 20 LTD 5-1/2IN DW TRACK 1IN LEG 550PDT100-19 and attributes length 5.5 and gauge 20
# Added document 178/9813 with name ProTRAK 20 LTD 6IN DRYWALL TRACK 1IN LEG 600PDT100-19 and attributes length 6.0 and gauge 20
# Added document 179/9813 with name ProTRAK 22MIL-33EQ 6 DRYWALL TRACK 1 LEG 600PDT100-22 (33EQ) and attributes length None and gauge 22
# Added document 180/9813 with name ProTRAK 20 LTD 3-1/2IN DW TR 1-1/2IN LEG 350PDT150-19 and attributes length 3.5 and gauge 20
# Added document 181/9813 with name ProTRAK 22MIL-33EQ 3-1/2 DW TRK 1-1/2LEG 350PDT150-22 (33EQ) and attributes length 3.5 and gauge 22
# Added document 182/9813 with name ProTRAK 20 LTD 1-5/8IN DW TR 1-1/4IN LEG 162PDT125-19 and attributes length 1.25 and gauge 20
# Added document 183/9813 with name ProTRAK 22MIL-33EQ 1-5/8 DW TRK 1-1/4LEG 162PDT125-22 (33EQ) and attributes length 1.25 and gauge 22
# Added document 184/9813 with name ProTRAK 20 LTD 2-1/2IN DW TR 1-1/4IN LEG 250PDT125-19 and attributes length 2.5 and gauge 20
# Added document 185/9813 with name ProTRAK 22MIL-33EQ 2-1/2 DW TRK 1-1/4LEG 250PDT125-22 (33EQ) and attributes length 2.5 and gauge 22
# Added document 186/9813 with name ProTRAK 20 LTD 3-5/8IN DW TR 1-1/4IN LEG 362PDT125-19 and attributes length 3.625 and gauge 20
# Added document 187/9813 with name ProTRAK 22MIL-33EQ 3-5/8 DW TRK 1-1/4LEG 362PDT125-22 (33EQ) and attributes length 1.25 and gauge 22
# Added document 188/9813 with name ProTRAK 20 LTD 4IN DW TRACK 1-1/4IN LEG 400PDT125-19 and attributes length 4.0 and gauge 20
# Added document 189/9813 with name ProTRAK 22MIL-33EQ 4 DW TRACK 1-1/4 LEG 400PDT125-22 (33EQ) and attributes length 1.25 and gauge 22
# Added document 190/9813 with name ProTRAK 20 LTD 5-1/2IN DW TR 1-1/4IN LEG 550PDT125-19 and attributes length 5.5 and gauge 20
# Added document 191/9813 with name ProTRAK 20 LTD 6IN DW TRACK 1-1/4IN LEG 600PDT125-19 and attributes length 6.0 and gauge 20
# Added document 192/9813 with name ProTRAK 22MIL-33EQ 6 DW TRACK 1-1/4 LEG 600PDT125-22 (33EQ) and attributes length 1.25 and gauge 22
# Added document 193/9813 with name ProTRAK 20 LTD 3-1/2IN DW TR 1-1/4IN LEG 350PDT125-19 and attributes length 3.5 and gauge 20
# Added document 194/9813 with name ProTRAK 20 LTD 3-5/8IN DW TR 1-1/2IN LEG 362PDT150-19 and attributes length 3.625 and gauge 20
# Added document 195/9813 with name ProTRAK 22MIL-33EQ 3-5/8 DW TRK 1-1/2LEG 362PDT150-22 (33EQ) and attributes length 3.625 and gauge 22
# Added document 196/9813 with name ProTRAK 20 LTD 1-5/8IN DW TRACK 2IN LEG 162PDT200-19 and attributes length 2.5 and gauge 20
# Added document 197/9813 with name ProTRAK 22MIL-33EQ 1-5/8 DW TRACK 2 LEG 162PDT200-22 (33EQ) and attributes length 1.625 and gauge 22
# Added document 198/9813 with name ProTRAK 20 LTD 2-1/2IN DW TRACK 2IN LEG 250PDT200-19 and attributes length 2.5 and gauge 20
# Added document 199/9813 with name ProTRAK 22MIL-33EQ 2-1/2 DW TRACK 2 LEG 250PDT200-22 (33EQ) and attributes length 2.5 and gauge 22
# Added document 200/9813 with name ProTRAK 20 LTD 3-5/8IN DW TRACK 2IN LEG 362PDT200-19 and attributes length 3.625 and gauge 20
# Added document 201/9813 with name ProTRAK 22MIL-33EQ 3-5/8 DW TRACK 2 LEG 362PDT200-22 (33EQ) and attributes length 3.625 and gauge 22
# Added document 202/9813 with name ProTRAK 20 LTD 4IN DRYWALL TRACK 2IN LEG 400PDT200-19 and attributes length 4.0 and gauge 20
# Added document 203/9813 with name ProTRAK 22MIL-33EQ 4 DRYWALL TRACK 2 LEG 400PDT200-22 (33EQ) and attributes length None and gauge 22
# Added document 204/9813 with name ProTRAK 20 LTD 5-1/2IN DW TRACK 2IN LEG 550PDT200-19 and attributes length 5.5 and gauge 20
# Added document 205/9813 with name ProTRAK 20 LTD 6IN DRYWALL TRACK 2IN LEG 600PDT200-19 and attributes length 6.0 and gauge 20
# Added document 206/9813 with name ProTRAK 22MIL-33EQ 6 DRYWALL TRACK 2 LEG 600PDT200-22 (33EQ) and attributes length None and gauge 22
# Added document 207/9813 with name ProTRAK 20 LTD 3-1/2IN DW TRACK 2IN LEG 350PDT200-19 and attributes length 3.5 and gauge 20
# Added document 208/9813 with name ProSTUD 22MIL-33EQ 1-5/8 DW STUD 1-7/16 162PDS144-22 (33EQ) and attributes length 1.625 and gauge 22
# Added document 209/9813 with name ProSTUD 22MIL-33EQ 2-1/2 DW STUD 1-7/16 250PDS144-22 (33EQ) and attributes length 2.5 and gauge 22
# Added document 210/9813 with name ProSTUD 22MIL-33EQ 3-5/8 DW STUD 1-7/16 362PDS144-22 (33EQ) and attributes length 3.625 and gauge 22
# Added document 211/9813 with name ProSTUD 22MIL-33EQ 4 DW STUD 1-7/16 400PDS144-22 (33EQ) and attributes length 1.4375 and gauge 22
# Added document 212/9813 with name ProSTUD 22MIL-33EQ 5-1/2 DW STUD 1-7/16 550PDS144-22 (33EQ) and attributes length 5.5 and gauge 22
# Added document 213/9813 with name ProSTUD 22MIL-33EQ 6 DW STUD 1-7/16 600PDS144-22 (33EQ) and attributes length 1.4375 and gauge 22
# Added document 214/9813 with name ProSTUD 22MIL-33EQ 3-1/2 DW STUD 1-7/16 350PDS144-22 (33EQ) and attributes length 3.5 and gauge 22
# Added document 215/9813 with name ProTRAK 20 LTD 1-5/8IN DW TR 2-1/2IN LEG 162PDT250-19 and attributes length 2.5 and gauge 20
# Added document 216/9813 with name ProTRAK 20 LTD 2-1/2IN DW TR 2-1/2IN LEG 250PDT250-19 and attributes length 2.5 and gauge 20
# Added document 217/9813 with name ProTRAK 20 LTD 3-5/8IN DW TR 2-1/2IN LEG 362PDT250-19 and attributes length 2.5 and gauge 20
# Added document 218/9813 with name ProTRAK 20 LTD 4IN DW TRACK 2-1/2IN LEG 400PDT250-19 and attributes length 2.5 and gauge 20
# Added document 219/9813 with name ProTRAK 20 LTD 3-1/2IN DW TR 2-1/2IN LEG 350PDT250-19 and attributes length 2.5 and gauge 20
# Added document 220/9813 with name ProTRAK 20 LTD 6IN DW TRACK 2-1/2IN LEG 600PDT250-19 and attributes length 6.0 and gauge 20
# Added document 221/9813 with name ProTRAK 22MIL-33EQ 6 DW TRACK 2-1/2 LEG 600PDT250-22 (33EQ) and attributes length 2.5 and gauge 22
# Added document 222/9813 with name ProTRAK 20 LTD 1-5/8IN DW TRACK 3IN LEG 162PDT300-19 and attributes length 3.0 and gauge 20
# Added document 223/9813 with name ProTRAK 20 LTD 2-1/2IN DW TRACK 3IN LEG 250PDT300-19 and attributes length 2.5 and gauge 20
# Added document 224/9813 with name ProTRAK 20 LTD 3-5/8IN DW TRACK 3IN LEG 362PDT300-19 and attributes length 3.625 and gauge 20
# Added document 225/9813 with name ProTRAK 22MIL-33EQ 3-5/8 DW TRACK 3 LEG 362PDT300-22 (33EQ) and attributes length 3.625 and gauge 22
# Added document 226/9813 with name ProTRAK 20 LTD 4IN DRYWALL TRACK 3IN LEG 400PDT300-19 and attributes length 4.0 and gauge 20
# Added document 227/9813 with name ProTRAK 20 LTD 6IN DRYWALL TRACK 3IN LEG 600PDT300-19 and attributes length 6.0 and gauge 20
# Added document 228/9813 with name ProTRAK 22MIL-33EQ 6 DRYWALL TRACK 3 LEG 600PDT300-22 (33EQ) and attributes length None and gauge 22
# Added document 229/9813 with name STR STD 6IN 20G 1-5/8IN FL 2-1/2IN PUNCH 600S162-33 (20G) 2.5 IN PUNCH and attributes length 2.5 and gauge 20
# Added document 230/9813 with name STR STD 6IN 18G 1-5/8IN FL 2-1/2IN PUNCH 600S162-43 (18G) 2.5 IN PUNCH and attributes length 2.5 and gauge 18
# Added document 231/9813 with name STR STUD 6IN 16G 1-5/8IN FL 2-1/2 PUNCH 600S162-54 (16G) and attributes length 2.5 and gauge 16
# Added document 232/9813 with name STR STD 6IN 14G 1-5/8IN FL 2-1/2IN PUNCH 600S162-68 (14G) 2.5 IN PUNCH and attributes length 2.5 and gauge 14
# Added document 233/9813 with name STR STD 6IN 12G 1-5/8IN FL 2-1/2IN PUNCH 600S162-97 (12G) 2.5 IN PUNCH and attributes length 2.5 and gauge 12
# Added document 234/9813 with name STR STD 8IN 16G 1-5/8IN FL 2-1/2IN PUNCH 800S162-54 (16G) 2.5 IN PUNCH and attributes length 2.5 and gauge 16
# Added document 235/9813 with name STRUCTURAL STUD 9IN 14G 1-5/8IN FL 900S162-68 (14G) and attributes length 9.0 and gauge 14
# Added document 236/9813 with name 12FT RESILIENT CHANNEL 1/2IN X 2-1/4IN nan and attributes length 144.0 and gauge 0
# Added document 237/9813 with name CONTOUR TRACK 250-20 nan and attributes length 250.0 and gauge 20
# Added document 238/9813 with name CONTOUR TRACK 362-20 nan and attributes length 362.0 and gauge 20
# Added document 239/9813 with name CONTOUR TRACK 600-20 nan and attributes length None and gauge 20
# Added document 240/9813 with name ProSTUD 25 1-5/8IN DRYWALL STUD 162PDS125-15 and attributes length 1.625 and gauge 25
# Added document 241/9813 with name ProSTUD 20 1-5/8IN DRYWALL STUD 20 162PDS125-22 and attributes length 1.625 and gauge 20
# Added document 242/9813 with name ProSTUD 33MIL 1-5/8IN DRYWALL STUD 162PDS125-33 and attributes length 1.625 and gauge 33
# Added document 243/9813 with name ProSTUD 30MIL 1-5/8IN DRYWALL STUD 162PDS125-30 and attributes length 1.625 and gauge 30
# Added document 244/9813 with name ProSTUD 25 2-1/2IN DRYWALL STUD 250PDS125-15 and attributes length 2.5 and gauge 25
# Added document 245/9813 with name ProSTUD 22 2-1/2IN DRYWALL STUD 22 250PDS125-18 and attributes length 2.5 and gauge 22
# Added document 246/9813 with name ProSTUD 20 2-1/2IN DRYWALL STUD 20 250PDS125-22 and attributes length 2.5 and gauge 20
# Added document 247/9813 with name ProSTUD 33MIL 2-1/2IN DRYWALL STUD 250PDS125-33 and attributes length 2.5 and gauge 33
# Added document 248/9813 with name ProSTUD 30MIL 2-1/2IN DRYWALL STUD 250PDS125-30 and attributes length 2.5 and gauge 30
# Added document 249/9813 with name ProSTUD 25 3-5/8IN DRYWALL STUD 362PDS125-15 and attributes length 3.625 and gauge 25
# Added document 250/9813 with name ProSTUD 22 3-5/8IN DRYWALL STUD 22 362PDS125-18 and attributes length 3.625 and gauge 22
# Added document 251/9813 with name ProSTUD 20 3-5/8IN DRYWALL STUD 20 362PDS125-22 and attributes length 3.625 and gauge 20
# Added document 252/9813 with name ProSTUD 33MIL 3-5/8IN DRYWALL STUD 362PDS125-33 and attributes length 3.625 and gauge 33
# Added document 253/9813 with name ProSTUD 30MIL 3-5/8IN DRYWALL STUD 362PDS125-30 and attributes length 3.625 and gauge 30
# Added document 254/9813 with name ProSTUD 25 4IN DRYWALL STUD 400PDS125-15 and attributes length 4.0 and gauge 25
# Added document 255/9813 with name ProSTUD 22 4IN DRYWALL STUD 22 400PDS125-18 and attributes length 4.0 and gauge 22
# Added document 256/9813 with name ProSTUD 33MIL 4IN DRYWALL STUD 400PDS125-33 and attributes length 4.0 and gauge 33
# Added document 257/9813 with name ProSTUD 30MIL 4IN DRYWALL STUD 400PDS125-30 and attributes length 4.0 and gauge 30
# Added document 258/9813 with name ProSTUD 25 6IN DRYWALL STUD 600PDS125-15 and attributes length 6.0 and gauge 25
# Added document 259/9813 with name ProSTUD 22 6IN DRYWALL STUD 22 600PDS125-18 and attributes length 6.0 and gauge 22
# Added document 260/9813 with name ProSTUD 33MIL 6IN DRYWALL STUD 600PDS125-33 and attributes length 6.0 and gauge 33
# Added document 261/9813 with name ProSTUD 30MIL 6IN DRYWALL STUD 600PDS125-30 and attributes length 6.0 and gauge 30
# Added document 262/9813 with name ProSTUD 25 3-1/2IN DRYWALL STUD 350PDS125-15 and attributes length 3.5 and gauge 25
# Added document 263/9813 with name ProSTUD 33MIL 3-1/2IN DRYWALL STUD 350PDS125-33 and attributes length 3.5 and gauge 33
# Added document 264/9813 with name ProSTUD 30MIL 3-1/2IN DRYWALL STUD 350PDS125-30 and attributes length 3.5 and gauge 30
# Added document 265/9813 with name ProSTUD 25 5-1/2IN DRYWALL STUD 550PDS125-15 and attributes length 5.5 and gauge 25
# Added document 266/9813 with name ProSTUD 22 5-1/2IN DRYWALL STUD 22 550PDS125-18 and attributes length 5.5 and gauge 22
# Added document 267/9813 with name ProSTUD 33MIL 5-1/2IN DRYWALL STUD 550PDS125-33 and attributes length 5.5 and gauge 33
# Added document 268/9813 with name ProSTUD 30MIL 5-1/2IN DRYWALL STUD 550PDS125-30 and attributes length 5.5 and gauge 30
# Added document 269/9813 with name ProTRAK 25 1-5/8IN DW TRACK 1-1/2IN LEG 162PDT150-15 and attributes length 1.5 and gauge 25
# Added document 270/9813 with name ProTRAK 33MIL 1-5/8IN DW TRK 1-1/2IN LEG 162PDT150-33 and attributes length 1.5 and gauge 33
# Added document 271/9813 with name ProTRAK 30MIL 1-5/8IN DW TRK 1-1/2IN LEG 162PDT150-30 and attributes length 1.5 and gauge 30
# Added document 272/9813 with name ProTRAK 25 2-1/2IN DW TRACK 1-1/2IN LEG 250PDT150-15 and attributes length 2.5 and gauge 1
# Added document 273/9813 with name ProTRAK 20 2-1/2IN DW TRACK 1-1/2IN LEG 20 250PDT150-22 and attributes length 2.5 and gauge 20
# Added document 274/9813 with name ProTRAK 33MIL 2-1/2IN DW TRK 1-1/2IN LEG 250PDT150-33 and attributes length 2.5 and gauge 33
# Added document 275/9813 with name ProTRAK 30MIL 2-1/2IN DW TRK 1-1/2IN LEG 250PDT150-30 and attributes length 2.5 and gauge 30
# Added document 276/9813 with name ProTRAK 25 4IN DRYWALL TRACK 1-1/2IN LEG 400PDT150-15 and attributes length 4.0 and gauge 1
# Added document 277/9813 with name ProTRAK 20 4IN DRYWALL TRACK 1-1/2IN LEG 20 400PDT150-22 and attributes length 4.0 and gauge 20
# Added document 278/9813 with name ProTRAK 33MIL 4IN DW TRACK 1-1/2IN LEG 400PDT150-33 and attributes length 4.0 and gauge 33
# Added document 279/9813 with name ProTRAK 30MIL 4IN DW TRACK 1-1/2IN LEG 400PDT150-30 and attributes length 4.0 and gauge 30
# Added document 280/9813 with name ProTRAK 25 6IN DRYWALL TRACK 1-1/2IN LEG 600PDT150-15 and attributes length 6.0 and gauge 1
# Added document 281/9813 with name ProTRAK 20 6IN DRYWALL TRACK 1-1/2IN LEG 20 600PDT150-22 and attributes length 6.0 and gauge 20
# Added document 282/9813 with name ProTRAK 33MIL 6IN DW TRACK 1-1/2IN LEG 600PDT150-33 and attributes length 6.0 and gauge 33
# Added document 283/9813 with name ProTRAK 30MIL 6IN DW TRACK 1-1/2IN LEG 600PDT150-30 and attributes length 6.0 and gauge 30
# Added document 284/9813 with name 8FT PAPER FACED INSIDE CORNER BEAD nan and attributes length 96.0 and gauge None
# Added document 285/9813 with name ProTRAK 25 1-5/8IN DRYWALL TRACK 1IN LEG 162PDT100-15 and attributes length 1.625 and gauge 25
# Added document 286/9813 with name ProTRAK 33MIL 1-5/8IN DW TRACK 1IN LEG 162PDT100-33 and attributes length 1.625 and gauge 33
# Added document 287/9813 with name ProTRAK 30MIL 1-5/8IN DW TRACK 1IN LEG 162PDT100-30 and attributes length 1.625 and gauge 30
# Added document 288/9813 with name ProTRAK 25 2-1/2IN DRYWALL TRACK 1IN LEG 250PDT100-15 and attributes length 2.5 and gauge 25
# Added document 289/9813 with name ProTRAK 33MIL 2-1/2IN DW TRACK 1IN LEG 250PDT100-33 and attributes length 2.5 and gauge 33
# Added document 290/9813 with name ProTRAK 25 3-5/8IN DRYWALL TRACK 1IN LEG 362PDT100-15 and attributes length 3.625 and gauge 25
# Added document 291/9813 with name ProTRAK 33MIL 3-5/8IN DW TRACK 1IN LEG 362PDT100-33 and attributes length 3.625 and gauge 33
# Added document 292/9813 with name ProTRAK 30MIL 3-5/8IN DW TRACK 1IN LEG 362PDT100-30 and attributes length 3.625 and gauge 30
# Added document 293/9813 with name ProTRAK 25 4IN DRYWALL TRACK 1IN LEG 400PDT100-15 and attributes length 4.0 and gauge 25
# Added document 294/9813 with name ProTRAK 33MIL 4IN DRYWALL TRACK 1IN LEG 400PDT100-33 and attributes length 4.0 and gauge 33
# Added document 295/9813 with name ProTRAK 30MIL 4IN DRYWALL TRACK 1IN LEG 400PDT100-30 and attributes length 4.0 and gauge 30
# Added document 296/9813 with name ProTRAK 25 6IN DRYWALL TRACK 1IN LEG 600PDT100-15 and attributes length 6.0 and gauge 25
# Added document 297/9813 with name ProTRAK 33MIL 6IN DRYWALL TRACK 1IN LEG 600PDT100-33 and attributes length 6.0 and gauge 33
# Added document 298/9813 with name ProTRAK 30MIL 6IN DRYWALL TRACK 1IN LEG 600PDT100-30 and attributes length 6.0 and gauge 30
# Added document 299/9813 with name ProTRAK 25 2IN DRYWALL TRACK 1IN LEG 200PDT100-15 and attributes length 2.0 and gauge 25
# Added document 300/9813 with name ProTRAK 20 2IN DRYWALL TRACK 1IN LEG 20 200PDT100-22 and attributes length 2.0 and gauge 20
# Added document 301/9813 with name ProTRAK 25 1-5/8IN DW TRACK 1-1/4IN LEG 25 162PDT125-15 and attributes length 1.625 and gauge 25
# Added document 302/9813 with name ProTRAK 20 1-5/8IN DW TRACK 1-1/4IN LEG 20 162PDT125-22 and attributes length 1.25 and gauge 20
# Added document 303/9813 with name ProTRAK 33MIL 1-5/8IN DW TRK 1-1/4IN LEG 162PDT125-33 and attributes length 1.25 and gauge 33
# Added document 304/9813 with name ProTRAK 30MIL 1-5/8IN DW TRK 1-1/4IN LEG 162PDT125-30 and attributes length 1.25 and gauge 30
# Added document 305/9813 with name ProTRAK 25 2-1/2IN DW TRACK 1-1/4IN LEG 25 250PDT125-15 and attributes length 2.5 and gauge 1
# Added document 306/9813 with name ProTRAK 22 2-1/2IN DW TRACK 1-1/4IN LEG 22 250PDT125-18 and attributes length 2.5 and gauge 22
# Added document 307/9813 with name ProTRAK 20 2-1/2IN DW TRACK 1-1/4IN LEG 20 250PDT125-22 and attributes length 2.5 and gauge 20
# Added document 308/9813 with name ProTRAK 33MIL 2-1/2IN DW TRK 1-1/4IN LEG 250PDT125-33 and attributes length 2.5 and gauge 33
# Added document 309/9813 with name ProTRAK 30MIL 2-1/2IN DW TRK 1-1/4IN LEG 250PDT125-30 and attributes length 2.5 and gauge 30
# Added document 310/9813 with name ProTRAK 25 3-5/8IN DW TRACK 1-1/4IN LEG 25 362PDT125-15 and attributes length 3.625 and gauge 25
# Added document 311/9813 with name ProTRAK 20 3-5/8IN DW TRACK 1-1/4IN LEG 20 362PDT125-22 and attributes length 3.625 and gauge 20
# Added document 312/9813 with name ProTRAK 33MIL 3-5/8IN DW TRK 1-1/4IN LEG 362PDT125-33 and attributes length 3.625 and gauge 33
# Added document 313/9813 with name ProTRAK 30MIL 3-5/8IN DW TRK 1-1/4IN LEG 362PDT125-30 and attributes length 3.625 and gauge 30
# Added document 314/9813 with name ProTRAK 25 4IN DRYWALL TRACK 1-1/4IN LEG 25 400PDT125-15 and attributes length 4.0 and gauge 1
# Added document 315/9813 with name ProTRAK 33MIL 4IN DW TRACK 1-1/4IN LEG 400PDT125-33 and attributes length 4.0 and gauge 33
# Added document 316/9813 with name ProTRAK 30MIL 4IN DW TRACK 1-1/4IN LEG 400PDT125-30 and attributes length 4.0 and gauge 30
# Added document 317/9813 with name ProTRAK 25 5-1/2IN DW TRACK 1-1/4IN LEG 25 550PDT125-15 and attributes length 5.5 and gauge 1
# Added document 318/9813 with name ProTRAK 20 5-1/2IN DW TRACK 1-1/4IN LEG 20 550PDT125-22 and attributes length 5.5 and gauge 20
# Added document 319/9813 with name ProTRAK 33MIL 5-1/2IN DW TRK 1-1/4IN LEG 550PDT125-33 and attributes length 5.5 and gauge 33
# Added document 320/9813 with name ProTRAK 30MIL 5-1/2IN DW TRK 1-1/4IN LEG 550PDT125-30 and attributes length 5.5 and gauge 30
# Added document 321/9813 with name ProTRAK 25 6IN DRYWALL TRACK 1-1/4IN LEG 25 600PDT125-15 and attributes length 6.0 and gauge None
# Added document 322/9813 with name ProTRAK 22 6IN DRYWALL TRACK 1-1/4IN LEG 22 600PDT125-18 and attributes length 6.0 and gauge 22
# Added document 323/9813 with name ProTRAK 33MIL 6IN DW TRACK 1-1/4IN LEG 600PDT125-33 and attributes length 6.0 and gauge 33
# Added document 324/9813 with name ProTRAK 30MIL 6IN DW TRACK 1-1/4IN LEG 600PDT125-30 and attributes length 6.0 and gauge 30
# Added document 325/9813 with name ProTRAK 22 6IN DW TRK 1-1/4IN LEG HEMMED nan and attributes length 6.0 and gauge 22
# Added document 326/9813 with name ProTRAK 25 3-1/2IN DW TRACK 1-1/4IN LEG 25 350PDT125-15 and attributes length 3.5 and gauge 25
# Added document 327/9813 with name ProTRAK 33MIL 3-1/2IN DW TRK 1-1/4IN LEG 350PDT125-33 and attributes length 3.5 and gauge 33
# Added document 328/9813 with name ProTRAK 30MIL 3-1/2IN DW TRK 1-1/4IN LEG 350PDT125-30 and attributes length 3.5 and gauge 30
# Added document 329/9813 with name ProTRAK 25 3-5/8IN DW TRACK 1-1/2IN LEG 362PDT150-15 and attributes length 3.625 and gauge 25
# Added document 330/9813 with name ProTRAK 20 3-5/8IN DW TRACK 1-1/2IN LEG 20 362PDT150-22 and attributes length 3.625 and gauge 20
# Added document 331/9813 with name ProTRAK 33MIL 3-5/8IN DW TRK 1-1/2IN LEG 362PDT150-33 and attributes length 3.625 and gauge 33
# Added document 332/9813 with name ProTRAK 30MIL 3-5/8IN DW TRK 1-1/2IN LEG 362PDT150-30 and attributes length 3.625 and gauge 30
# Added document 333/9813 with name ProTRAK 25 1-5/8IN DRYWALL TRACK 2IN LEG 162PDT200-15 and attributes length 1.625 and gauge 25
# Added document 334/9813 with name ProTRAK 33MIL 1-5/8IN DW TRACK 2IN LEG 162PDT200-33 and attributes length 1.625 and gauge 33
# Added document 335/9813 with name ProTRAK 30MIL 1-5/8IN DW TRACK 2IN LEG 162PDT200-30 and attributes length 2.5 and gauge 30
# Added document 336/9813 with name ProTRAK 25 2-1/2IN DRYWALL TRACK 2IN LEG 250PDT200-15 and attributes length 2.5 and gauge 25
# Added document 337/9813 with name ProTRAK 20 2-1/2IN DRYWALL TRACK 2IN LEG 20 250PDT200-22 and attributes length 2.5 and gauge 20
# Added document 338/9813 with name ProTRAK 33MIL 2-1/2IN DW TRACK 2IN LEG 250PDT200-33 and attributes length 2.5 and gauge 33
# Added document 339/9813 with name ProTRAK 30MIL 2-1/2IN DW TRACK 2IN LEG 250PDT200-30 and attributes length 2.5 and gauge 30
# Added document 340/9813 with name ProTRAK 25 3-5/8IN DRYWALL TRACK 2IN LEG 362PDT200-15 and attributes length 3.625 and gauge 25
# Added document 341/9813 with name ProTRAK 22 3-5/8IN DRYWALL TRACK 2IN LEG 22 362PDT200-18 and attributes length 3.625 and gauge 22
# Added document 342/9813 with name ProTRAK 20 3-5/8IN DRYWALL TRACK 2IN LEG 20 362PDT200-22 and attributes length 3.625 and gauge 20
# Added document 343/9813 with name ProTRAK 33MIL 3-5/8IN DW TRACK 2IN LEG 362PDT200-33 and attributes length 3.625 and gauge 33
# Added document 344/9813 with name ProTRAK 30MIL 3-5/8IN DW TRACK 2IN LEG 362PDT200-30 and attributes length 3.625 and gauge 30
# Added document 345/9813 with name ProTRAK 25 4IN DRYWALL TRACK 2IN LEG 400PDT200-15 and attributes length 4.0 and gauge 25
# Added document 346/9813 with name ProTRAK 20 4IN DRYWALL TRACK 2IN LEG 20 400PDT200-22 and attributes length 4.0 and gauge 20
# Added document 347/9813 with name ProTRAK 33MIL 4IN DRYWALL TRACK 2IN LEG 400PDT200-33 and attributes length 4.0 and gauge 33
# Added document 348/9813 with name ProTRAK 30MIL 4IN DRYWALL TRACK 2IN LEG 400PDT200-30 and attributes length 4.0 and gauge 30
# Added document 349/9813 with name ProTRAK 25 5-1/2IN DRYWALL TRACK 2IN LEG 550PDT200-15 and attributes length 5.5 and gauge 25
# Added document 350/9813 with name ProTRAK 30MIL 5-1/2IN DW TRACK 2IN LEG 550PDT200-30 and attributes length 5.5 and gauge 30
# Added document 351/9813 with name ProTRAK 25 6IN DRYWALL TRACK 2IN LEG 600PDT200-15 and attributes length 6.0 and gauge 25
# Added document 352/9813 with name ProTRAK 33MIL 6IN DRYWALL TRACK 2IN LEG 600PDT200-33 and attributes length 6.0 and gauge 33
# Added document 353/9813 with name ProTRAK 30MIL 6IN DRYWALL TRACK 2IN LEG 600PDT200-30 and attributes length 6.0 and gauge 30
# Added document 354/9813 with name ProTRAK 25 3-1/2IN DRYWALL TRACK 2IN LEG 350PDT200-15 and attributes length 3.5 and gauge 25
# Added document 355/9813 with name ProTRAK 33MIL 3-1/2IN DW TRACK 2IN LEG 350PDT200-33 and attributes length 3.5 and gauge 33
# Added document 356/9813 with name ProTRAK 30MIL 3-1/2IN DW TRACK 2IN LEG 350PDT200-30 and attributes length 3.5 and gauge 30
# Added document 357/9813 with name ProTRAK 25 1-5/8IN DWT 1-1/4IN LEG HEM 162PDT125-15 and attributes length 1.25 and gauge 25
# Added document 358/9813 with name ProTRAK 25 2-1/2IN DWT 1-1/4IN LEG HEM 250PDT125-15 and attributes length 2.5 and gauge 1
# Added document 359/9813 with name ProTRAK 25 3-5/8IN DWT 1-1/4IN LEG HEM 362PDT125-15 and attributes length 3.625 and gauge 25
# Added document 360/9813 with name ProTRAK 25 4IN DRY TRACK 1-1/4IN LEG HEM 25 400PDT125-15 and attributes length 4.0 and gauge 1
# Added document 361/9813 with name ProTRAK 25 5-1/2IN DWT 1-1/4IN LEG HEM 550PDT125-15 and attributes length 5.5 and gauge 1
# Added document 362/9813 with name ProTRAK 25 6IN DRY TRACK 1-1/4IN LEG HEM 600PDT125-15 and attributes length 6.0 and gauge 1
# Added document 363/9813 with name ProTRAK 25 3-1/2IN DWT 1-1/4IN LEG HEM 350PDT125-15 and attributes length 3.5 and gauge 1
# Added document 364/9813 with name ProTRAK 25 1-5/8IN DW TRACK 2-1/2IN LEG 162PDT250-15 and attributes length 2.5 and gauge 25
# Added document 365/9813 with name ProTRAK 33MIL 1-5/8IN DW TRK 2-1/2IN LEG 162PDT250-33 and attributes length 2.5 and gauge 33
# Added document 366/9813 with name ProTRAK 30MIL 1-5/8IN DW TRK 2-1/2IN LEG 162PDT250-30 and attributes length 2.5 and gauge 30
# Added document 367/9813 with name ProTRAK 25 2-1/2IN DW TRACK 2-1/2IN LEG 250PDT250-15 and attributes length 2.5 and gauge 25
# Added document 368/9813 with name ProTRAK 33MIL 2-1/2IN DW TRK 2-1/2IN LEG 250PDT250-33 and attributes length 2.5 and gauge 33
# Added document 369/9813 with name ProTRAK 30MIL 2-1/2IN DW TRK 2-1/2IN LEG 250PDT250-30 and attributes length 2.5 and gauge 30
# Added document 370/9813 with name ProTRAK 25 3-5/8IN DW TRACK 2-1/2IN LEG 362PDT250-15 and attributes length 2.5 and gauge 25
# Added document 371/9813 with name ProTRAK 33MIL 3-5/8IN DW TRK 2-1/2IN LEG 362PDT250-33 and attributes length 2.5 and gauge 33
# Added document 372/9813 with name ProTRAK 30MIL 3-5/8IN DW TRK 2-1/2IN LEG 362PDT250-30 and attributes length 2.5 and gauge 30
# Added document 373/9813 with name ProTRAK 25 4IN DRYWALL TRACK 2-1/2IN LEG 400PDT250-15 and attributes length 2.5 and gauge 25
# Added document 374/9813 with name ProTRAK 33MIL 4IN DW TRACK 2-1/2IN LEG 400PDT250-33 and attributes length 2.5 and gauge 33
# Added document 375/9813 with name ProTRAK 30MIL 4IN DW TRACK 2-1/2IN LEG 400PDT250-30 and attributes length 2.5 and gauge 30
# Added document 376/9813 with name ProTRAK 25 6IN DRYWALL TRACK 2-1/2IN LEG 600PDT250-15 and attributes length 2.5 and gauge 25
# Added document 377/9813 with name ProTRAK 20 6IN DRYWALL TRACK 2-1/2IN LEG 20 600PDT250-22 and attributes length 6.0 and gauge 20
# Added document 378/9813 with name ProTRAK 33MIL 6IN DW TRACK 2-1/2IN LEG 600PDT250-33 and attributes length 2.5 and gauge 33
# Added document 379/9813 with name ProTRAK 30MIL 6IN DW TRACK 2-1/2IN LEG 600PDT250-30 and attributes length 6.0 and gauge 30
# Added document 380/9813 with name ProTRAK 25 1-5/8IN DRYWALL TRACK 3IN LEG 162PDT300-15 and attributes length 3.0 and gauge 25
# Added document 381/9813 with name ProTRAK 33MIL 1-5/8IN DW TRACK 3IN LEG 162PDT300-33 and attributes length 1.625 and gauge 33
# ...
# Cell In[9], line 7
#       5 name = product_name + " " + alias
#       6 get_attr_prompt = get_attr_prompt_template.invoke({'product_name': name})
# ----> 7 parsed_attributes = structured_llm.invoke(get_attr_prompt)
#       8 attr_dict = dict(parsed_attributes)
#       9 metadata = {key:val for key, val in attr_dict.items() if val is not None}
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/langchain_core/runnables/base.py:3027, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3025 context.run(_set_config_context, config)
#    3026 if i == 0:
# -> 3027     input = context.run(step.invoke, input, config, **kwargs)
#    3028 else:
#    3029     input = context.run(step.invoke, input, config)
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/langchain_core/runnables/base.py:5365, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5359 def invoke(
#    5360     self,
#    5361     input: Input,
#    5362     config: Optional[RunnableConfig] = None,
#    5363     **kwargs: Optional[Any],
#    5364 ) -> Output:
# -> 5365     return self.bound.invoke(
#    5366         input,
#    5367         self._merge_configs(config),
#    5368         **{**self.kwargs, **kwargs},
#    5369     )
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:307, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     296 def invoke(
#     297     self,
#     298     input: LanguageModelInput,
#    (...)    302     **kwargs: Any,
#     303 ) -> BaseMessage:
#     304     config = ensure_config(config)
#     305     return cast(
#     306         ChatGeneration,
# --> 307         self.generate_prompt(
#     308             [self._convert_input(input)],
#     309             stop=stop,
#     310             callbacks=config.get("callbacks"),
#     311             tags=config.get("tags"),
#     312             metadata=config.get("metadata"),
#     313             run_name=config.get("run_name"),
#     314             run_id=config.pop("run_id", None),
#     315             **kwargs,
#     316         ).generations[0][0],
#     317     ).message
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:837, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     829 def generate_prompt(
#     830     self,
#     831     prompts: list[PromptValue],
#    (...)    834     **kwargs: Any,
#     835 ) -> LLMResult:
#     836     prompt_messages = [p.to_messages() for p in prompts]
# --> 837     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:679, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     676 for i, m in enumerate(messages):
#     677     try:
#     678         results.append(
# --> 679             self._generate_with_cache(
#     680                 m,
#     681                 stop=stop,
#     682                 run_manager=run_managers[i] if run_managers else None,
#     683                 **kwargs,
#     684             )
#     685         )
#     686     except BaseException as e:
#     687         if run_managers:
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:902, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     900 else:
#     901     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 902         result = self._generate(
#     903             messages, stop=stop, run_manager=run_manager, **kwargs
#     904         )
#     905     else:
#     906         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:815, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     813 payload.pop("stream")
#     814 try:
# --> 815     response = self.root_client.beta.chat.completions.parse(**payload)
#     816 except openai.BadRequestError as e:
#     817     _handle_openai_bad_request(e)
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/openai/resources/beta/chat/completions.py:161, in Completions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     154 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#     155     return _parse_chat_completion(
#     156         response_format=response_format,
#     157         chat_completion=raw_completion,
#     158         input_tools=tools,
#     159     )
# --> 161 return self._post(
#     162     "/chat/completions",
#     163     body=maybe_transform(
#     164         {
#     165             "messages": messages,
#     166             "model": model,
#     167             "audio": audio,
#     168             "frequency_penalty": frequency_penalty,
#     169             "function_call": function_call,
#     170             "functions": functions,
#     171             "logit_bias": logit_bias,
#     172             "logprobs": logprobs,
#     173             "max_completion_tokens": max_completion_tokens,
#     174             "max_tokens": max_tokens,
#     175             "metadata": metadata,
#     176             "modalities": modalities,
#     177             "n": n,
#     178             "parallel_tool_calls": parallel_tool_calls,
#     179             "prediction": prediction,
#     180             "presence_penalty": presence_penalty,
#     181             "reasoning_effort": reasoning_effort,
#     182             "response_format": _type_to_response_format(response_format),
#     183             "seed": seed,
#     184             "service_tier": service_tier,
#     185             "stop": stop,
#     186             "store": store,
#     187             "stream": False,
#     188             "stream_options": stream_options,
#     189             "temperature": temperature,
#     190             "tool_choice": tool_choice,
#     191             "tools": tools,
#     192             "top_logprobs": top_logprobs,
#     193             "top_p": top_p,
#     194             "user": user,
#     195         },
#     196         completion_create_params.CompletionCreateParams,
#     197     ),
#     198     options=make_request_options(
#     199         extra_headers=extra_headers,
#     200         extra_query=extra_query,
#     201         extra_body=extra_body,
#     202         timeout=timeout,
#     203         post_parser=parser,
#     204     ),
#     205     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     206     # in the `parser` function above
#     207     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     208     stream=False,
#     209 )
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/openai/_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/openai/_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/openai/_base_client.py:955, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     952 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     954 try:
# --> 955     response = self._client.send(
#     956         request,
#     957         stream=stream or self._should_stream_response_body(request=request),
#     958         **kwargs,
#     959     )
#     960 except httpx.TimeoutException as err:
#     961     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Documents/Personal/endeavor/finalinterview/.venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1292     if flags != 0:
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#    1298     return super().recv(buflen, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1167         return self._sslobj.read(len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#    1171     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
